# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("/home/chaitanya/Downloads/archive/tourism.csv")
df.head()
# Out:
#            Name      Region          Type  airport_dist(km)  railway_dist(km)  \
# 0         Kufri  North East  Hill Station              20.0             100.0
# 1  Wilson Hills        West  Hill Station             122.0              60.0
# 2   Paithalmala       South  Hill Station             159.0              39.0
# 3       Ponmudi       South  Hill Station              51.0              33.0
# 4     Ranipuram       South  Hill Station             125.0              55.0
#
#    Elevation(m)  rating
# 0        2210.0     7.0
# 1         750.0     8.0
# 2        1372.0     9.0
# 3        1100.0     9.0
# 4        1022.0     9.0

# %%
df.dropna()
# Out:
#                                        Name      Region             Type  \
# 0                                     Kufri  North East     Hill Station
# 1                              Wilson Hills        West     Hill Station
# 2                               Paithalmala       South     Hill Station
# 3                                   Ponmudi       South     Hill Station
# 4                                 Ranipuram       South     Hill Station
# 5                                    Manali       North     Hill Station
# 6                                   Gulmarg       North     Hill Station
# 7                               Dharamshala  North East     Hill Station
# 8                                 Lansdowne  North East     Hill Station
# 9                                      Auli  North East     Hill Station
# 10                               Darjeeling  North East     Hill Station
# 11         Jawaharlal Nehru Biological Park        East  Zoological Park
# ...

# %%
x = df['Region'].astype(str) + ' ' + df['Type'].astype(str)
y=df['Name']

# %%
vectorizer = CountVectorizer()

# Convert text to numerical features
X_vectorized = vectorizer.fit_transform(x.values.astype('U'))

# %%
x_train, x_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

# %%
classifier = MultinomialNB()
classifier.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
# Get the probability estimates for each class\
example_input="beach"
example_input_vectorized = vectorizer.transform([example_input])
proba = classifier.predict_proba(example_input_vectorized)[0]

# Get the top N classes with the highest probabilities
N = 3  # Number of top predictions you want
top_N_indices = proba.argsort()[-N:][::-1]
predicted_destinations = [classifier.classes_[idx] for idx in top_N_indices]

print("Top Predicted Travel Destinations:")
for destination in predicted_destinations:
    print(destination)
# Out:
# Top Predicted Travel Destinations:
# Agonda beach
# Puri Beach
# Elephanta Beach

# %%
import joblib 
joblib.dump(classifier,'model.joblib')
joblib.dump(vectorizer,'vectorizer.joblib')
# Out:
# ['vectorizer.joblib']
